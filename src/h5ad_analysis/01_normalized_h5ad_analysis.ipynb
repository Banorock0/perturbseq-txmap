# %%
# single cell analysis package
# for h5ad matrices

import scanpy as sc

# %%
# This takes way too much compute and memory
# Look at subset or seek to access cluster

perturb_seq = sc.read_h5ad(filename = "../../processed/provided_data/K562_gwps_normalized_singlecell_01.h5ad",
backed = "r")
